# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/VTO/Data-pre-processing/Human-Parsing
# Out:
# /content/drive/MyDrive/VTO/Data-pre-processing/Human-Parsing

# %%
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 4.3 MB/s eta 0:00:00

# %%
# !python3 simple_extractor.py --dataset 'lip' --model-restore 'lip_final.pth' --input-dir 'input-folder' --output-dir 'output-folder'
# Out:
# 100% 2/2 [00:07<00:00,  3.99s/it]
